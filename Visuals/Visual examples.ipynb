# %% [markdown]
# # Visual1
# To compactly visualize each genre against each economic feature
# Think color=genre; line=economic feature; dots = genre consumption

# %%
# Dependencies
import pandas as pd
import seaborn as sns
sns.set()

# %%
penguins = sns.load_dataset("penguins")
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
# Plot sepal width as a function of sepal_length across days
g = sns.lmplot(
    data=penguins,
    x="bill_length_mm", y="bill_depth_mm", hue="species",
    height=5
)

# Use more informative axis labels than are provided by default
g.set_axis_labels("Snoot length (mm)", "Snoot depth (mm)")

# %%
# Load the dataset
genres_df = pd.read_csv("Resources/Movies-Cleaned-Final.csv")
genres_df
# Out:
#       Date1     Date2  Total Gross              Genre
# 0     01/06  Jan-2006   64724295.0             Action
# 1     02/06  Feb-2006    8357325.0             Action
# 2     03/06  Mar-2006  125928240.0             Action
# 3     04/06  Apr-2006       2220.0             Action
# 4     05/06  May-2006  368533435.0             Action
# ...     ...       ...          ...                ...
# 1075  08/20  Aug-2020   20950415.0  Thriller/Suspense
# 1076  09/20  Sep-2020    4821467.0  Thriller/Suspense
# 1077  10/20  Oct-2020   15566724.0  Thriller/Suspense
# 1078  11/20  Nov-2020   10927115.0  Thriller/Suspense
# 1079  12/20  Dec-2020    3089694.0  Thriller/Suspense
#
# [1080 rows x 4 columns]

# %%
# Plot sepal width as a function of sepal_length across days
g = sns.lmplot(
    data=genres_df,
    x="Date2", y="Total Gross", hue="Genre",
    height=5
)

# Use more informative axis labels than are provided by default
g.set_axis_labels("Snoot length (mm)", "Snoot depth (mm)")


### PROBLEM IS THAT X AND Y MUST BE SAME DATATYPE

# %%
# Use more informative axis labels than are provided by default
g.set_axis_labels("Snoot length (mm)", "Snoot depth (mm)")

# %%
ec_df = pd.read_csv("df_econ.csv")
ec_df
# Out:
#      Unnamed: 0  inflation  S&Pyield  unemployment  UMCSENT  homeindex  \
# 0        200001   0.000000 -0.610843           4.0    111.3     0.0646
# 1        200002   0.068802 -0.241297           4.1    107.1     0.0646
# 2        200003   0.096717  1.160638           4.0    109.2     0.0646
# 3        200004   0.009360 -0.369549           3.8    110.7     0.0666
# 4        200005   0.009353 -0.262981           4.0    106.4     0.0666
# ..          ...        ...       ...           ...      ...        ...
# 247      202008   0.037833  0.840776           8.4     80.4     0.0808
# 248      202009   0.016722 -0.470736           7.8     81.8     0.0808
# 249      202010   0.004987 -0.331989           6.9     76.9     0.1077
# 250      202011  -0.007338  1.290548           6.7     80.7     0.1077
# 251      202012   0.011268  0.445458           6.7     79.0     0.1077
#
#      UMCSENT.1
# 0        111.3
# 1        107.1
# 2        109.2
# 3        110.7
# 4        106.4
# ..         ...
# ...

# %%
g = sns.lmplot(
    data=ec_df,
    x="inflation", y="homeindex", hue="species",
    height=5
)

# Use more informative axis labels than are provided by default
g.set_axis_labels("Snoot length (mm)", "Snoot depth (mm)")

# %% [markdown]
# # Visual2
# When extraneous genres/ec features have been eliminated from 1st visual, view all those with correlations, as below
# THINK: x=time; line1= genre consumption; line2=Economic feature (NOTE: Layered scales will be needed on y-axis)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

rs = np.random.RandomState(365)
values = rs.randn(365, 4).cumsum(axis=0)
dates = pd.date_range("1 1 2016", periods=365, freq="D")
data = pd.DataFrame(values, dates, columns=["A", "B", "C", "D"])
data = data.rolling(7).mean()

sns.lineplot(data=data, palette="tab10", linewidth=2.5)

# %%
ec_df = pd.read_csv("df_econ.csv")
ec_df
# Out:
#      Unnamed: 0  inflation  S&Pyield  unemployment  UMCSENT  homeindex  \
# 0        200001   0.000000 -0.610843           4.0    111.3     0.0646
# 1        200002   0.068802 -0.241297           4.1    107.1     0.0646
# 2        200003   0.096717  1.160638           4.0    109.2     0.0646
# 3        200004   0.009360 -0.369549           3.8    110.7     0.0666
# 4        200005   0.009353 -0.262981           4.0    106.4     0.0666
# ..          ...        ...       ...           ...      ...        ...
# 247      202008   0.037833  0.840776           8.4     80.4     0.0808
# 248      202009   0.016722 -0.470736           7.8     81.8     0.0808
# 249      202010   0.004987 -0.331989           6.9     76.9     0.1077
# 250      202011  -0.007338  1.290548           6.7     80.7     0.1077
# 251      202012   0.011268  0.445458           6.7     79.0     0.1077
#
#      UMCSENT.1
# 0        111.3
# 1        107.1
# 2        109.2
# 3        110.7
# 4        106.4
# ..         ...
# ...

# %%
ec_df.drop(ec_df.columns[0], axis=1, inplace=True)
ec_df.dtypes
# Out:
# inflation       float64
# S&Pyield        float64
# unemployment    float64
# UMCSENT         float64
# homeindex       float64
# UMCSENT.1       float64
# dtype: object

# %%
ec_df['inflation'] = ec_df['inflation'].apply(lambda x: x*10)
ec_df['unemployment'] = ec_df['unemployment'].apply(lambda x: x*.1)
ec_df['UMCSENT'] = ec_df['UMCSENT'].apply(lambda x: x*0.01)
ec_df['homeindex'] = ec_df['homeindex'].apply(lambda x: x*10)
ec_df['UMCSENT.1'] = ec_df['UMCSENT.1'].apply(lambda x: x*0.01)
ec_df
# Out:
#      inflation  S&Pyield  unemployment  UMCSENT  homeindex  UMCSENT.1
# 0     0.000000 -0.610843          0.40    1.113      0.646      1.113
# 1     0.688019 -0.241297          0.41    1.071      0.646      1.071
# 2     0.967171  1.160638          0.40    1.092      0.646      1.092
# 3     0.093604 -0.369549          0.38    1.107      0.666      1.107
# 4     0.093531 -0.262981          0.40    1.064      0.666      1.064
# ..         ...       ...           ...      ...        ...        ...
# 247   0.378328  0.840776          0.84    0.804      0.808      0.804
# 248   0.167223 -0.470736          0.78    0.818      0.808      0.818
# 249   0.049866 -0.331989          0.69    0.769      1.077      0.769
# 250  -0.073384  1.290548          0.67    0.807      1.077      0.807
# 251   0.112683  0.445458          0.67    0.790      1.077      0.790
#
# [252 rows x 6 columns]

# %%
# rs = np.random.RandomState(365)
# ec_values = rs.randn(365, 4).cumsum(axis=0)
# ec_data = pd.DataFrame(values, Unnamed: 0, columns=["inflation", "S&Pyield", "unemployment", "UMCSENT", "homeindex", "UMCSENT.1"])
#ec_data = ec_df.rolling(7).mean()

sns.lineplot(data=ec_df, palette="tab10", linewidth=2.5)

# %%
import matplotlib.pyplot as plt
fig = plt.gcf()

# Change seaborn plot size
fig.set_size_inches(12, 8)

sns.lineplot(data=ec_df, palette="tab10", linewidth=2.5)

# %%
Action = ec_df.drop(ec_df.columns[0], axis=1, inplace=True)
Action

# %%
ec_df
fig = plt.gcf()
fig.set_size_inches(12, 8)

sns.lineplot(data=ec_df, palette="tab10", linewidth=2.5)

# %% [markdown]
# # Visual3
# To see how most impactful economic feature related to all genres
# THINK: x=time; line=Economic feature; dot = genres (each genre is a different color)

# %%
import numpy as np
import seaborn as sns
sns.set(style="whitegrid")

# Make an example dataset with y ~ x
rs = np.random.RandomState(7)
x = rs.normal(2, 1, 75)
y = 2 + 1.5 * x + rs.normal(0, 2, 75)

# Plot the residuals after fitting a linear model
sns.residplot(x=x, y=y, lowess=True, color="g")
